# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bowling_df=pd.read_csv(r"C:\Users\RISHABH\OneDrive\Desktop\DATA\python\T20 world Cup2022\t20_csv_files\fact_bowling_summary.csv")

# %%
batting_df=pd.read_csv(r"C:\Users\RISHABH\OneDrive\Desktop\DATA\python\T20 world Cup2022\t20_csv_files\fact_bating_summary.csv")

# %%
batting_df['innings']=1

# %%
batting_df['out/not_out']=batting_df['out/not_out'].replace(['out','not_out'],[1,0])

# %%
batting_df
# Out:
#                     match teamInnings  battingPos             batsmanName  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5         Gerhard Erasmus
# ..                    ...         ...         ...                     ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
#      runs  balls  4s  6s      SR  out/not_out     match_id  innings
# 0       3      6   0   0      50            1  T20I # 1823        1
# 1       9      9   1   0     100            1  T20I # 1823        1
# 2      20     12   1   2  166.66            1  T20I # 1823        1
# 3      26     24   2   0  108.33            1  T20I # 1823        1
# 4      20     24   0   0   83.33            1  T20I # 1823        1
# ..    ...    ...  ..  ..     ...          ...          ...      ...
# 694    10      9   2   0  111.11            1  T20I # 1879        1
# 695    52     49   5   1  106.12            0  T20I # 1879        1
# 696    20     23   1   0   86.95            1  T20I # 1879        1
# 697    19     13   3   0  146.15            1  T20I # 1879        1
# 698     1      1   0   0     100            0  T20I # 1879        1
#
# [699 rows x 12 columns]

# %%
batting_stats=batting_df.groupby('batsmanName').sum('runs').sort_values('runs',ascending=False)

# %%
batting_stats

batting_stats.sort_values('6s',ascending=False)
# Out:
#                       battingPos  runs  balls  4s  6s  out/not_out  innings
# batsmanName
# Sikandar Raza                 39   219    148  16  11            8        8
# Kusal Mendis                  15   223    156  17  10            7        8
# Alex Hales                    12   212    144  19  10            5        6
# Andy Balbirnie                14   153    123  10   9            7        7
# Rilee Rossouw                 12   141     83   9   9            4        4
# ...                          ...   ...    ...  ..  ..          ...      ...
# Matthew Wade                  21    15     15   2   0            2        3
# Logan van Beek                34    15     23   0   0            2        4
# Darwish Rasooli                7    15     13   1   0            1        1
# Mohammad Wasim                24    16     22   2   0            2        3
# Danushka Gunathilaka           4     0      1   0   0            1        1
#
# [201 rows x 7 columns]

# %%
batting_stats['BattingAvg']=(batting_stats['runs'] / batting_stats['out/not_out'])

# %%
batting_stats['StrikeRate']=(batting_stats['runs'] / batting_stats['balls'])*100

# %%
batting_stats.drop(columns=['battingPos','out/not_out'],inplace=True)

# %%
batting_stats['BoundaryRuns']=4*(batting_stats['4s'])+6*(batting_stats['6s'])

# %%
batting_stats['%runsinboundary']=(batting_stats['BoundaryRuns']/batting_stats['runs'])*100

# %%
batting_stats['avgbowlsfaced/inn']=batting_stats['balls']/batting_stats['innings']

# %%
batting_stats['6hittingrate']=batting_stats['balls']/batting_stats['6s']

# %%
batting_stats['4hittingrate']=batting_stats['balls']/batting_stats['4s']

# %%
batting_stats['non-boundaryruns']=batting_stats['runs']-batting_stats['BoundaryRuns']

batting_stats.reset_index(inplace=True)

batting_stats
# Out:
#               batsmanName  runs  balls  4s  6s  innings  BattingAvg  \
# 0             Virat Kohli   296    217  25   8        6   98.666667
# 1              Max O'Dowd   242    215  22   8        8   34.571429
# 2        Suryakumar Yadav   239    126  26   9        6   59.750000
# 3             Jos Buttler   225    156  24   7        6   45.000000
# 4            Kusal Mendis   223    156  17  10        8   31.857143
# ..                    ...   ...    ...  ..  ..      ...         ...
# 196          Hasan Mahmud     0      5   0   0        2    0.000000
# 197        Alzarri Joseph     0      1   0   0        1    0.000000
# 198        Mohammed Shami     0      2   0   0        1    0.000000
# 199         Naveen-ul-Haq     0      0   0   0        1         NaN
# 200  Danushka Gunathilaka     0      1   0   0        1    0.000000
#
#      StrikeRate  BoundaryRuns  %runsinboundary  avgbowlsfaced/inn  \
# 0    136.405530           148        50.000000          36.166667
# 1    112.558140           136        56.198347          26.875000
# 2    189.682540           158        66.108787          21.000000
# 3    144.230769           138        61.333333          26.000000
# 4    142.948718           128        57.399103          19.500000
# ..          ...           ...              ...                ...
# 196    0.000000             0              NaN           2.500000
# 197    0.000000             0              NaN           1.000000
# 198    0.000000             0              NaN           2.000000
# 199         NaN             0              NaN           0.000000
# 200    0.000000             0              NaN           1.000000
#
#      6hittingrate  4hittingrate  non-boundaryruns
# 0       27.125000      8.680000               148
# 1       26.875000      9.772727               106
# 2       14.000000      4.846154                81
# 3       22.285714      6.500000                87
# 4       15.600000      9.176471                95
# ..            ...           ...               ...
# 196           inf           inf                 0
# 197           inf           inf                 0
# 198           inf           inf                 0
# 199           NaN           NaN                 0
# 200           inf           inf                 0
#
# [201 rows x 14 columns]

# %%
batting_stats['non-boundarystrikerate']=((batting_stats['non-boundaryruns'])*100)/(batting_stats['balls']-(batting_stats['4s']+batting_stats['6s']))

# %%
player_data=pd.read_csv(r"C:\Users\RISHABH\OneDrive\Desktop\DATA\python\T20 world Cup2022\t20_csv_files\dim_players.csv")
duplicate = player_data[player_data.duplicated('name')]
player_data=player_data.drop_duplicates()
batting_stats=pd.merge(batting_stats,player_data,left_on="batsmanName", right_on="name")
batting_stats.drop(columns=['bowlingStyle','description','name','image'],inplace=True) 

batting_stats
# Out:
#               batsmanName  runs  balls  4s  6s  innings  BattingAvg  \
# 0             Virat Kohli   296    217  25   8        6   98.666667
# 1              Max O'Dowd   242    215  22   8        8   34.571429
# 2        Suryakumar Yadav   239    126  26   9        6   59.750000
# 3             Jos Buttler   225    156  24   7        6   45.000000
# 4            Kusal Mendis   223    156  17  10        8   31.857143
# ..                    ...   ...    ...  ..  ..      ...         ...
# 193          Hasan Mahmud     0      5   0   0        2    0.000000
# 194        Alzarri Joseph     0      1   0   0        1    0.000000
# 195        Mohammed Shami     0      2   0   0        1    0.000000
# 196         Naveen-ul-Haq     0      0   0   0        1         NaN
# 197  Danushka Gunathilaka     0      1   0   0        1    0.000000
#
#      StrikeRate  BoundaryRuns  %runsinboundary  avgbowlsfaced/inn  \
# 0    136.405530           148        50.000000          36.166667
# 1    112.558140           136        56.198347          26.875000
# 2    189.682540           158        66.108787          21.000000
# 3    144.230769           138        61.333333          26.000000
# 4    142.948718           128        57.399103          19.500000
# ..          ...           ...              ...                ...
# 193    0.000000             0              NaN           2.500000
# 194    0.000000             0              NaN           1.000000
# 195    0.000000             0              NaN           2.000000
# 196         NaN             0              NaN           0.000000
# 197    0.000000             0              NaN           1.000000
#
#      6hittingrate  4hittingrate  non-boundaryruns  non-boundarystrikerate  \
# 0       27.125000      8.680000               148               80.434783
# 1       26.875000      9.772727               106               57.297297
# 2       14.000000      4.846154                81               89.010989
# 3       22.285714      6.500000                87               69.600000
# 4       15.600000      9.176471                95               73.643411
# ..            ...           ...               ...                     ...
# 193           inf           inf                 0                0.000000
# 194           inf           inf                 0                0.000000
# 195           inf           inf                 0                0.000000
# 196           NaN           NaN                 0                     NaN
# 197           inf           inf                 0                0.000000
#
#             team    battingStyle          playingRole
# 0          India  Right hand Bat     Top order Batter
# 1    Netherlands  Right hand Bat       Opening Batter
# 2          India  Right hand Bat               Batter
# 3        England  Right hand Bat  Wicketkeeper Batter
# 4      Sri Lanka  Right hand Bat  Wicketkeeper Batter
# ..           ...             ...                  ...
# 193   Bangladesh  Right hand Bat               Bowler
# 194  West Indies  Right hand Bat               Bowler
# 195        India  Right hand Bat               Bowler
# 196  Afghanistan  Right hand Bat               Bowler
# 197    Sri Lanka   Left hand Bat           Allrounder
#
# [198 rows x 18 columns]

# %%
top30batsmen=batting_stats.head(30)

# %%
top30batsmen
# Out:
#               batsmanName  runs  balls  4s  6s  innings  BattingAvg  \
# 0             Virat Kohli   296    217  25   8        6   98.666667
# 1              Max O'Dowd   242    215  22   8        8   34.571429
# 2        Suryakumar Yadav   239    126  26   9        6   59.750000
# 3             Jos Buttler   225    156  24   7        6   45.000000
# 4            Kusal Mendis   223    156  17  10        8   31.857143
# 5           Sikandar Raza   219    148  16  11        8   27.375000
# 6         Pathum Nissanka   214    196  13   8        7   30.571429
# 7              Alex Hales   212    144  19  10        6   42.400000
# 8           Lorcan Tucker   204    163  19   4        7   40.800000
# 9          Glenn Phillips   201    127  19   8        5   40.200000
# 10  Najmul Hossain Shanto   180    157  20   2        5   36.000000
# 11        Kane Williamson   178    153  11   5        5   35.600000
# 12    Dhananjaya de Silva   177    137  15   4        8   25.285714
# 13            Shan Masood   175    148  12   1        7   43.750000
# 14        Mohammad Rizwan   175    160  15   3        7   25.000000
# 15          Paul Stirling   170    127  16   6        7   28.333333
# 16        Colin Ackermann   165    149  13   4        8   23.571429
# 17          Sean Williams   155    137  14   2        8   19.375000
# 18         Andy Balbirnie   153    123  10   9        7   21.857143
# 27     52.500000      7.500000                57               64.044944
# 28           inf     10.153846                72               60.504202
# 29     15.400000      4.812500                30               53.571429
#
#             team    battingStyle          playingRole
# 0          India  Right hand Bat     Top order Batter
# 1    Netherlands  Right hand Bat       Opening Batter
# 2          India  Right hand Bat               Batter
# 3        England  Right hand Bat  Wicketkeeper Batter
# 4      Sri Lanka  Right hand Bat  Wicketkeeper Batter
# 5       Zimbabwe  Right hand Bat   Batting Allrounder
# 6      Sri Lanka  Right hand Bat     Top order Batter
# 7        England  Right hand Bat       Opening Batter
# 8        Ireland  Right hand Bat  Wicketkeeper Batter
# 9    New Zealand  Right hand Bat  Wicketkeeper Batter
# 10    Bangladesh   Left hand Bat     Top order Batter
# 11   New Zealand  Right hand Bat     Top order Batter
# 12     Sri Lanka  Right hand Bat           Allrounder
# 13      Pakistan   Left hand Bat       Opening Batter
# 14      Pakistan  Right hand Bat  Wicketkeeper Batter
# 15       Ireland  Right hand Bat   Batting Allrounder
# 16   Netherlands  Right hand Bat   Batting Allrounder
# 17      Zimbabwe   Left hand Bat  Middle order Batter
# 18       Ireland  Right hand Bat               Batter
# 19   New Zealand   Left hand Bat  Wicketkeeper Batter
# 20  South Africa   Left hand Bat     Top order Batter
# 21     Sri Lanka   Left hand Bat   Batting Allrounder
# 22         India  Right hand Bat       Opening Batter
# 23         India  Right hand Bat           Allrounder
# 24    Bangladesh  Right hand Bat  Wicketkeeper Batter
# 25       Ireland  Right hand Bat           Allrounder
# 26     Australia  Right hand Bat   Batting Allrounder
# 27     Sri Lanka   Left hand Bat     Top order Batter
# 28      Pakistan  Right hand Bat               Batter
# 29  South Africa   Left hand Bat  Wicketkeeper Batter

# %%
Avg=top30batsmen['BattingAvg']
SR=top30batsmen['StrikeRate']
name=top30batsmen['batsmanName']
nonboundary=top30batsmen['non-boundarystrikerate']

plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,10))
plt.scatter(Avg,SR)
plt.xlabel('Batting Average')
plt.ylabel('Strike Rate')
plt.title('batsmen comparison ')
for i in range(top30batsmen.shape[0]):
     text=plt.text(x=Avg[i]+0.3,y=SR[i]+0.3,s=name[i],
                fontdict=dict(color='red',size=5))
        
plt.tight_layout()

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12,12))
plt.scatter(nonboundary,SR)
plt.xlabel('non-Boundary Strike Rate')
plt.ylabel('Strike Rate')
plt.title('Strike Rate Comparison ')
for i in range(top30batsmen.shape[0]):
     text=plt.text(x=nonboundary[i]+0.3,y=SR[i]+0.3,s=name[i],
                fontdict=dict(color='red',size=5))
        
plt.tight_layout()

# %%
name=top30batsmen['batsmanName']
fours=top30batsmen['4s']
sixes=top30batsmen['6s']

x_index=np.arange(len(name))
width=0.2 
plt.figure(figsize=(14,10))
plt.style.use("seaborn-v0_8-whitegrid")
plt.bar(x_index + width, fours ,width=width,label='4s')
plt.bar(x_index - width, sixes ,width=width,label='6s')
plt.xticks(ticks=x_index, labels= name) 
plt.xlabel('batsmen')
plt.xticks(rotation=60)
plt.ylabel('Boundaries')
plt.legend() 
plt.grid(True)

plt.title('no. of boundaries scored')
plt.tight_layout()

# %%
colors=['blue'] 
plt.figure(figsize=(14,8)) 
plt.xlabel('Batsmen') 
plt.ylabel('% of runs scored through boundaries') 
plt.xticks(rotation=60) 
plt.style.use('ggplot') 
plt.stackplot(top30batsmen['batsmanName'],top30batsmen['%runsinboundary'] ,colors=colors) 

plt.title('Runs through Boundaries') 
plt.tight_layout()

# %%
plt.style.use('seaborn-bright') 
plt.figure(figsize=(14,7))
plt.bar(top30batsmen['batsmanName'],top30batsmen['avgbowlsfaced/inn'] )

plt.xlabel('batsmen')
plt.ylabel('Balls Played')
plt.xticks(rotation=60)
plt.grid(True)
plt.title('Avg balls faced in Inning')
plt.tight_layout()

# %%
plt.figure(figsize=(14,8))


top30batsmen=top30batsmen.sort_values('6hittingrate',ascending=False)
plt.subplot(1,2,1)

plt.style.use('seaborn')
plt.barh(top30batsmen['batsmanName'],top30batsmen['6hittingrate'])

plt.xlabel('Balls faced to hit a Six')
plt.ylabel('batsman')

plt.grid(True)

plt.title('Avg balls per Sixes')
plt.tight_layout()


top30batsmen=top30batsmen.sort_values('4hittingrate',ascending=False)
plt.subplot(1,2,2)


plt.style.use('seaborn')
plt.barh(top30batsmen['batsmanName'],top30batsmen['4hittingrate'])

plt.xlabel('Balls faced to hit a four')
plt.ylabel('batsman')

plt.grid(True)

plt.title('Avg balls per four')
plt.tight_layout()

# %%
bowling_df['innings']=1

bowling_stats=bowling_df.groupby('bowlerName').sum('wickets').sort_values('wickets',ascending=False)

# %%
bowling_stats['dec'] = bowling_stats['overs'] % 1
bowling_stats['integer'] = bowling_stats['overs'] // 1
bowling_stats['overs2']=((bowling_stats['dec']/0.1)*(1/6))+bowling_stats['integer']
bowling_stats['bowling_Run_rate']=(bowling_stats['runs']/bowling_stats['overs2'])

# %%
bowling_stats['total_bowls_bowled']=(bowling_stats['dec']/0.1)+((bowling_stats['integer'])*6)

# %%
bowling_stats['StrikeRatebowling']=bowling_stats['runs']/bowling_stats['wickets']

# %%
bowling_stats['bowls per six']=bowling_stats['total_bowls_bowled']/bowling_stats['6s']

# %%
bowling_stats['bowls per four']=bowling_stats['total_bowls_bowled']/bowling_stats['4s']

# %%
bowling_stats['bowls per boundary']=bowling_stats['total_bowls_bowled']/(bowling_stats['4s']+bowling_stats['6s'])

bowling_stats['bowling_average']=bowling_stats['total_bowls_bowled']/bowling_stats['wickets']
bowling_stats.reset_index(inplace=True)

# %%
bowling_stats=pd.merge(bowling_stats,player_data,left_on="bowlerName", right_on="name")

# %%
bowling_stats.drop(columns=['battingStyle','description','name','image'],inplace=True)
bowling_stats
# Out:
#                      bowlerName  overs  maiden  runs  wickets  economy  0s  \
# 0    Wanindu Hasaranga de Silva   31.0       1   199       15    54.16  74
# 1                  Bas de Leede   22.0       0   169       13    55.15  50
# 2                    Sam Curran   22.4       0   148       13    39.80  66
# 3           Blessing Muzarabani   26.0       0   199       12    53.00  71
# 4             Paul van Meekeren   31.0       0   198       11    52.25  85
# ..                          ...    ...     ...   ...      ...      ...  ..
# 127               Calum MacLeod    1.0       0    11        0    11.00   0
# 128               Cameron Green    2.0       0    13        0     6.50   7
# 129              Shoriful Islam    4.0       0    57        0    14.25   7
# 130      Jan Nicol Loftie-Eaton    1.0       0     8        0     8.00   2
# 131                 Zawar Farid    2.5       0    24        0     8.47   2
#
#      4s  6s  wides  ...  bowling_Run_rate  total_bowls_bowled  \
# 0     9   8      0  ...          6.419355               186.0
# 1    14   4      7  ...          7.681818               132.0
# 2     9   5      3  ...          6.529412               136.0
# 3    21   5      4  ...          7.653846               156.0
# 4    15   3      5  ...          6.387097               186.0
# ..   ..  ..    ...  ...               ...                 ...
# 127   0   1      0  ...         11.000000                 6.0
# 128   1   1      0  ...          6.500000                12.0
# 129   4   4      2  ...         14.250000                24.0
# 130   1   0      0  ...          8.000000                 6.0
# 131   2   0      0  ...          8.470588                17.0
#
#      StrikeRatebowling  bowls per six  bowls per four  bowls per boundary  \
# 0            13.266667          23.25       20.666667           10.941176
# 1            13.000000          33.00        9.428571            7.333333
# 2            11.384615          27.20       15.111111            9.714286
# 3            16.583333          31.20        7.428571            6.000000
# 4            18.000000          62.00       12.400000           10.333333
# ..                 ...            ...             ...                 ...
# 127                inf           6.00             inf            6.000000
# 128                inf          12.00       12.000000            6.000000
# 129                inf           6.00        6.000000            3.000000
# 130                inf            inf        6.000000            6.000000
# 131                inf            inf        8.500000            8.500000
#
#      bowling_average         team                               bowlingStyle  \
# 0          12.400000    Sri Lanka                                   Legbreak
# 1          10.153846  Netherlands                      Right arm Fast medium
# 2          10.461538      England                       Left arm Medium fast
# 3          13.000000     Zimbabwe                      Right arm Fast medium
# 4          16.909091  Netherlands                      Right arm Fast medium
# ..               ...          ...                                        ...
# 127              inf     Scotland  Right arm Medium fast, Right arm Offbreak
# 128              inf    Australia                      Right arm Fast medium
# 129              inf   Bangladesh                       Left arm Medium fast
# 130              inf      Namibia                 Right arm Medium, Legbreak
# 131              inf       U.A.E.                           Right arm Medium
#
#             playingRole
# 0            Allrounder
# 1    Batting Allrounder
# 2            Allrounder
# 3                Bowler
# 4                Bowler
# ..                  ...
# 127    Top order Batter
# 128  Batting Allrounder
# 129              Bowler
# 130              Batter
# 131              Bowler
#
# [132 rows x 25 columns]

# %%
bowling_stats_top30=bowling_stats.head(30)

# %%
bowling_stats_top30
# Out:
#                     bowlerName  overs  maiden  runs  wickets  economy  0s  4s  \
# 0   Wanindu Hasaranga de Silva   31.0       1   199       15    54.16  74   9
# 1                 Bas de Leede   22.0       0   169       13    55.15  50  14
# 2                   Sam Curran   22.4       0   148       13    39.80  66   9
# 3          Blessing Muzarabani   26.0       0   199       12    53.00  71  21
# 4            Paul van Meekeren   31.0       0   198       11    52.25  85  15
# 5                  Josh Little   27.0       0   189       11    48.58  68  16
# 6                  Shadab Khan   26.0       0   165       11    45.25  59  13
# 7          Shaheen Shah Afridi   25.1       0   155       11    42.66  70  15
# 8                Anrich Nortje   17.3       0    94       11    26.35  58   3
# 9                Sikandar Raza   24.0       0   156       10    55.08  46   5
# 10              Arshdeep Singh   20.0       0   156       10    45.00  55  21
# 5       40.500000       10.125000            8.100000        14.727273
# 6       78.000000       12.000000           10.400000        14.181818
# 7      151.000000       10.066667            9.437500        13.727273
# 8       21.000000       35.000000           13.125000         9.545455
# 9       36.000000       28.800000           16.000000        14.400000
# 10      60.000000        5.714286            5.217391        12.000000
# 11      16.800000        9.333333            6.000000         9.333333
# 12      22.625000       22.625000           11.312500        20.111111
# 13      24.000000        8.842105            6.461538        18.666667
# 14      40.000000       10.909091            8.571429        13.333333
# 15      45.000000       12.000000            9.473684        22.500000
# 16      40.000000        7.500000            6.315789        15.000000
# 17      34.000000       10.200000            7.846154        12.750000
# 18      27.000000        6.352941            5.142857        13.500000
# 19      52.000000        9.176471            7.800000        19.500000
# 20      21.600000       10.800000            7.200000        13.500000
# 21      24.200000       11.000000            7.562500        17.285714
# 22      26.500000       10.600000            7.571429         7.571429
# 23      26.000000        6.000000            4.875000        11.142857
# 24      22.800000        7.600000            5.700000        16.285714
# 25      20.800000       11.555556            7.428571        14.857143
# 26      24.000000       10.285714            7.200000        12.000000
# 27      24.000000        6.000000            4.800000        16.000000
# 28      22.800000       10.363636            7.125000        19.000000
# 29      32.666667       12.250000            8.909091        16.333333
#
#             team            bowlingStyle         playingRole
# 0      Sri Lanka                Legbreak          Allrounder
# 1    Netherlands   Right arm Fast medium  Batting Allrounder
# 2        England    Left arm Medium fast          Allrounder
# 3       Zimbabwe   Right arm Fast medium              Bowler
# 4    Netherlands   Right arm Fast medium              Bowler
# 5        Ireland    Left arm Fast medium              Bowler
# 6       Pakistan                Legbreak          Allrounder
# 7       Pakistan           Left arm Fast              Bowler
# 8   South Africa          Right arm Fast              Bowler
# 9       Zimbabwe      Right arm Offbreak  Batting Allrounder
# 10         India    Left arm Medium fast              Bowler
# 11       England          Right arm Fast              Bowler
# 12     Sri Lanka      Right arm Offbreak              Bowler
# 13      Zimbabwe    Left arm Fast medium              Bowler
# 14   New Zealand  Slow Left arm Orthodox  Bowling Allrounder
# 15   Netherlands    Left arm Fast medium              Bowler
# 16   New Zealand    Left arm Fast medium              Bowler
# 17      Pakistan   Right arm Fast medium          Allrounder
# 18    Bangladesh          Right arm Fast              Bowler
# 19      Pakistan          Right arm Fast              Bowler
# 20         India   Right arm Medium fast          Allrounder
# 21     Sri Lanka          Right arm Fast              Bowler
# 22   Netherlands          Right arm Fast              Bowler
# 23  South Africa   Right arm Fast medium              Bowler
# 24   New Zealand          Right arm Fast              Bowler
# 25   New Zealand   Right arm Medium fast              Bowler
# 26   West Indies          Right arm Fast              Bowler
# 27    Bangladesh        Right arm Medium              Bowler
# 28    Bangladesh  Slow Left arm Orthodox          Allrounder
# 29       England   Right arm Fast medium          Allrounder
#
# [30 rows x 25 columns]

# %%
plt.figure(figsize=(14,7))
plt.style.use('seaborn-notebook')
plt.bar(bowling_stats_top30['bowlerName'],bowling_stats_top30['wickets'])
plt.plot(bowling_stats_top30['bowlerName'],bowling_stats_top30['bowling_Run_rate'],label='run rate',color='red')
plt.xlabel('bowlers')
plt.legend()
plt.xticks(rotation=55)
plt.ylabel('Run Rate/wickets taken')
plt.title('Bowling run rate and wickets taken ')
plt.tight_layout()

# %%
plt.figure(figsize=(14,8))
plt.subplot(1,3,1)

plt.style.use('seaborn')
plt.barh(bowling_stats_top30['bowlerName'],bowling_stats_top30['bowls per six'])

plt.xlabel('bowls per six')
plt.ylabel('bowler')

plt.grid(True)

plt.title('Avg balls per six')
plt.tight_layout()

plt.subplot(1,3,2)

plt.style.use('seaborn')
plt.barh(bowling_stats_top30['bowlerName'],bowling_stats_top30['bowls per four'])


plt.xlabel('bowls per four')
plt.ylabel('bowler')

plt.grid(True)

plt.title('Avg balls per four')


plt.subplot(1,3,3)
plt.style.use('seaborn')
plt.barh(bowling_stats_top30['bowlerName'],bowling_stats_top30['bowls per boundary'])


plt.xlabel('bowls per boundary')
plt.ylabel('bowler')

plt.grid(True)

plt.title('Avg balls per boundary')
plt.tight_layout()

# %%
name=bowling_stats_top30['bowlerName']
bavg=bowling_stats_top30['bowling_average']
bsr=bowling_stats_top30['StrikeRatebowling']

plt.style.use('fivethirtyeight')
plt.figure(figsize=(14,12))
plt.scatter(bavg,bsr)
plt.xlabel('bowling average')
plt.ylabel('bowling strike rate')
plt.title('bowling Comparison ')
for i in range(bowling_stats_top30.shape[0]):
     text=plt.text(x=bavg[i]+0.3,y=bsr[i]+0.3,s=name[i],
                fontdict=dict(color='red',size=6))
        
plt.tight_layout()

# %%
bowling_stats_top30['%dotballs']=(bowling_stats_top30['0s']/bowling_stats_top30['total_bowls_bowled'])*100
# Out:
# C:\Users\RISHABH\AppData\Local\Temp\ipykernel_18792\2712533527.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowling_stats_top30['%dotballs']=(bowling_stats_top30['0s']/bowling_stats_top30['total_bowls_bowled'])*100

# %%
bowling_stats_top30
# Out:
#                     bowlerName  overs  maiden  runs  wickets  economy  0s  4s  \
# 0   Wanindu Hasaranga de Silva   31.0       1   199       15    54.16  74   9
# 1                 Bas de Leede   22.0       0   169       13    55.15  50  14
# 2                   Sam Curran   22.4       0   148       13    39.80  66   9
# 3          Blessing Muzarabani   26.0       0   199       12    53.00  71  21
# 4            Paul van Meekeren   31.0       0   198       11    52.25  85  15
# 5                  Josh Little   27.0       0   189       11    48.58  68  16
# 6                  Shadab Khan   26.0       0   165       11    45.25  59  13
# 7          Shaheen Shah Afridi   25.1       0   155       11    42.66  70  15
# 8                Anrich Nortje   17.3       0    94       11    26.35  58   3
# 9                Sikandar Raza   24.0       0   156       10    55.08  46   5
# 10              Arshdeep Singh   20.0       0   156       10    45.00  55  21
# 11                   Mark Wood   14.0       0   108        9    31.24  43   9
# 12          Maheesh Theekshana   30.1       0   202        9    53.39  71   8
# 13             Richard Ngarava   28.0       1   197        9    63.66  89  19
# 14            Mitchell Santner   20.0       0   129        9    32.25  49  11
# 15               Fred Klaassen   30.0       0   191        8    51.16  93  15
# 16                 Trent Boult   20.0       0   148        8    37.00  56  16
# 17              Mohammad Wasim   17.0       0   124        8    44.00  42  10
# 18                Taskin Ahmed   18.0       1   131        8    38.74  64  17
# 15       12.000000            9.473684        22.500000   Netherlands
# 16        7.500000            6.315789        15.000000   New Zealand
# 17       10.200000            7.846154        12.750000      Pakistan
# 18        6.352941            5.142857        13.500000    Bangladesh
# 19        9.176471            7.800000        19.500000      Pakistan
# 20       10.800000            7.200000        13.500000         India
# 21       11.000000            7.562500        17.285714     Sri Lanka
# 22       10.600000            7.571429         7.571429   Netherlands
# 23        6.000000            4.875000        11.142857  South Africa
# 24        7.600000            5.700000        16.285714   New Zealand
# 25       11.555556            7.428571        14.857143   New Zealand
# 26       10.285714            7.200000        12.000000   West Indies
# 27        6.000000            4.800000        16.000000    Bangladesh
# 28       10.363636            7.125000        19.000000    Bangladesh
# 29       12.250000            8.909091        16.333333       England
#
#               bowlingStyle         playingRole  %dotballs
# 0                 Legbreak          Allrounder  39.784946
# 1    Right arm Fast medium  Batting Allrounder  37.878788
# 2     Left arm Medium fast          Allrounder  48.529412
# 3    Right arm Fast medium              Bowler  45.512821
# 4    Right arm Fast medium              Bowler  45.698925
# 5     Left arm Fast medium              Bowler  41.975309
# 6                 Legbreak          Allrounder  37.820513
# 7            Left arm Fast              Bowler  46.357616
# 8           Right arm Fast              Bowler  55.238095
# 9       Right arm Offbreak  Batting Allrounder  31.944444
# 10    Left arm Medium fast              Bowler  45.833333
# 11          Right arm Fast              Bowler  51.190476
# 12      Right arm Offbreak              Bowler  39.226519
# 13    Left arm Fast medium              Bowler  52.976190
# 14  Slow Left arm Orthodox  Bowling Allrounder  40.833333
# 15    Left arm Fast medium              Bowler  51.666667
# 16    Left arm Fast medium              Bowler  46.666667
# 17   Right arm Fast medium          Allrounder  41.176471
# 18          Right arm Fast              Bowler  59.259259
# 19          Right arm Fast              Bowler  44.230769
# 20   Right arm Medium fast          Allrounder  38.888889
# 21          Right arm Fast              Bowler  49.586777
# 22          Right arm Fast              Bowler  54.716981
# 23   Right arm Fast medium              Bowler  38.461538
# 24          Right arm Fast              Bowler  37.719298
# 25   Right arm Medium fast              Bowler  50.000000
# 26          Right arm Fast              Bowler  47.222222
# 27        Right arm Medium              Bowler  43.750000
# 28  Slow Left arm Orthodox          Allrounder  23.684211
# 29   Right arm Fast medium          Allrounder  42.857143
#
# [30 rows x 26 columns]

# %%
plt.style.use('seaborn-v0_8-notebook')
plt.figure(figsize=(14,7))
plt.bar(name,bowling_stats_top30['%dotballs'] ,edgecolor='black')#here we can see that bins are to be choosen and we can choose as we want  

plt.xlabel('name')
plt.xticks(rotation=55)
plt.ylabel('% of balls bowled were dots')
plt.title('Dot balls')
plt.tight_layout()

# %%
all_rounder_stats=pd.merge(batting_stats,bowling_stats,left_on="batsmanName", right_on="bowlerName")

# %%
all_rounder_stats
# Out:
#              batsmanName  runs_x  balls  4s_x  6s_x  innings_x  BattingAvg  \
# 0          Sikandar Raza     219    148    16    11          8   27.375000
# 1    Dhananjaya de Silva     177    137    15     4          8   25.285714
# 2        Colin Ackermann     165    149    13     4          8   23.571429
# 3          Sean Williams     155    137    14     2          8   19.375000
# 4       Charith Asalanka     131    113     9     2          7   26.200000
# ..                   ...     ...    ...   ...   ...        ...         ...
# 112     Fazalhaq Farooqi       0      2     0     0          1    0.000000
# 113         Hasan Mahmud       0      5     0     0          2    0.000000
# 114       Alzarri Joseph       0      1     0     0          1    0.000000
# 115       Mohammed Shami       0      2     0     0          1    0.000000
# 116        Naveen-ul-Haq       0      0     0     0          1         NaN
#
#      StrikeRate  BoundaryRuns  %runsinboundary  ...  bowling_Run_rate  \
# 0    147.972973           130        59.360731  ...          6.500000
# 1    129.197080            84        47.457627  ...          6.821918
# 2    110.738255            76        46.060606  ...          5.285714
# 3    113.138686            68        43.870968  ...          6.166667
# 4    115.929204            48        36.641221  ...          8.000000
# ..          ...           ...              ...  ...               ...
# 112    0.000000             0              NaN  ...          6.521739
# 113    0.000000             0              NaN  ...          8.375000
# 114    0.000000             0              NaN  ...          6.916667
# 115    0.000000             0              NaN  ...          7.150000
# 116         NaN             0              NaN  ...          5.250000
#
#      total_bowls_bowled  StrikeRatebowling  bowls per six  bowls per four  \
# 0                 144.0          15.600000           36.0       28.800000
# 1                  73.0          13.833333           73.0       14.600000
# 2                  42.0          37.000000            inf       14.000000
# 3                 108.0          22.200000          108.0       27.000000
# 4                   6.0                inf            inf        6.000000
# ..                  ...                ...            ...             ...
# 112                69.0          25.000000           34.5        7.666667
# 113                96.0          22.333333           24.0        6.000000
# 114                72.0          13.833333           24.0       10.285714
# 115               120.0          23.833333           24.0        8.571429
# 116                24.0           7.000000            inf       12.000000
#
#     bowls per boundary bowling_average       team_y            bowlingStyle  \
# 0            16.000000       14.400000     Zimbabwe      Right arm Offbreak
# 1            12.166667       12.166667    Sri Lanka      Right arm Offbreak
# 2            14.000000       42.000000  Netherlands      Right arm Offbreak
# 3            21.600000       21.600000     Zimbabwe  Slow Left arm Orthodox
# 4             6.000000             inf    Sri Lanka      Right arm Offbreak
# ..                 ...             ...          ...                     ...
# 112           6.272727       23.000000  Afghanistan    Left arm Fast medium
# 113           4.800000       16.000000   Bangladesh        Right arm Medium
# 114           7.200000       12.000000  West Indies          Right arm Fast
# 115           6.315789       20.000000        India          Right arm Fast
# 116          12.000000        8.000000  Afghanistan   Right arm Medium fast
#
#            playingRole_y
# 0     Batting Allrounder
# 1             Allrounder
# 2     Batting Allrounder
# 3    Middle order Batter
# 4     Batting Allrounder
# ..                   ...
# 112               Bowler
# 113               Bowler
# 114               Bowler
# 115               Bowler
# 116               Bowler
#
# [117 rows x 43 columns]

# %%
all_rounder_stats['runs_scored']=all_rounder_stats['runs_x']
all_rounder_stats['runs_conceded']=all_rounder_stats['runs_y']

# %%
all_rounder_stats.drop(columns=['runs_x','runs_y'],inplace=True)

# %%
all_rounder_stats=all_rounder_stats[['bowlerName','runs_scored','BattingAvg', 'StrikeRate', '%runsinboundary', 'avgbowlsfaced/inn',
        'wickets','runs_conceded','overs', 'maiden', 'economy', 'bowling_Run_rate',
       'StrikeRatebowling', 'bowling_average','team_y','bowlingStyle','battingStyle']]

# %%
all_rounder_stats
# Out:
#               bowlerName  runs_scored  BattingAvg  StrikeRate  \
# 0          Sikandar Raza          219   27.375000  147.972973
# 1    Dhananjaya de Silva          177   25.285714  129.197080
# 2        Colin Ackermann          165   23.571429  110.738255
# 3          Sean Williams          155   19.375000  113.138686
# 4       Charith Asalanka          131   26.200000  115.929204
# ..                   ...          ...         ...         ...
# 112     Fazalhaq Farooqi            0    0.000000    0.000000
# 113         Hasan Mahmud            0    0.000000    0.000000
# 114       Alzarri Joseph            0    0.000000    0.000000
# 115       Mohammed Shami            0    0.000000    0.000000
# 116        Naveen-ul-Haq            0         NaN         NaN
#
#      %runsinboundary  avgbowlsfaced/inn  wickets  runs_conceded  overs  \
# 0          59.360731          18.500000       10            156   24.0
# 1          47.457627          17.125000        6             83   12.1
# 2          46.060606          18.625000        1             37    7.0
# 3          43.870968          17.125000        5            111   18.0
# 4          36.641221          16.142857        0              8    1.0
# ..               ...                ...      ...            ...    ...
# 112              NaN           2.000000        3             75   11.3
# 113              NaN           2.500000        6            134   16.0
# 114              NaN           1.000000        6             83   12.0
# 115              NaN           2.000000        6            143   20.0
# 116              NaN           0.000000        3             21    4.0
#
#      maiden  economy  bowling_Run_rate  StrikeRatebowling  bowling_average  \
# 0         0    55.08          6.500000          15.600000        14.400000
# 1         0    41.80          6.821918          13.833333        12.166667
# 2         0    14.99          5.285714          37.000000        42.000000
# 3         0    42.65          6.166667          22.200000        21.600000
# 4         0     8.00          8.000000                inf              inf
# ..      ...      ...               ...                ...              ...
# 112       1    19.53          6.521739          25.000000        23.000000
# 113       1    33.50          8.375000          22.333333        16.000000
# 114       0    20.75          6.916667          13.833333        12.000000
# 115       0    44.58          7.150000          23.833333        20.000000
# 116       0     5.25          5.250000           7.000000         8.000000
#
#           team_y            bowlingStyle    battingStyle
# 0       Zimbabwe      Right arm Offbreak  Right hand Bat
# 1      Sri Lanka      Right arm Offbreak  Right hand Bat
# 2    Netherlands      Right arm Offbreak  Right hand Bat
# 3       Zimbabwe  Slow Left arm Orthodox   Left hand Bat
# 4      Sri Lanka      Right arm Offbreak   Left hand Bat
# ..           ...                     ...             ...
# 112  Afghanistan    Left arm Fast medium  Right hand Bat
# 113   Bangladesh        Right arm Medium  Right hand Bat
# 114  West Indies          Right arm Fast  Right hand Bat
# 115        India          Right arm Fast  Right hand Bat
# 116  Afghanistan   Right arm Medium fast  Right hand Bat
#
# [117 rows x 17 columns]

# %%
all_rounder_stats = all_rounder_stats.rename(columns={'bowlerName':'Name'})

# %%
filt=all_rounder_stats['runs_scored']>40

# %%
all_rounder_stats=all_rounder_stats[filt]

# %%
filt2=all_rounder_stats['wickets']>=4

# %%
all_rounder_stats=all_rounder_stats[filt2]

# %%
all_rounder_stats.reset_index(inplace=True)

# %%
all_rounder_stats.drop(columns=['index'],inplace=True)

# %%
all_rounder_stats
# Out:
#                    Name  runs_scored  BattingAvg  StrikeRate  %runsinboundary  \
# 0         Sikandar Raza          219   27.375000  147.972973        59.360731
# 1   Dhananjaya de Silva          177   25.285714  129.197080        47.457627
# 2         Sean Williams          155   19.375000  113.138686        43.870968
# 3         Hardik Pandya          128   25.600000  131.958763        54.687500
# 4            Ben Stokes          110   36.666667  105.769231        30.909091
# 5           Shadab Khan           98   24.500000  168.965517        59.183673
# 6          Bas de Leede           93   18.600000   79.487179        36.559140
# 7         Gareth Delany           69   17.250000  127.777778        49.275362
# 8           Rashid Khan           57   28.500000  178.125000        70.175439
# 9     Paul van Meekeren           45   15.000000  166.666667        66.666667
# 10      Shakib Al Hasan           44    8.800000   95.652174        27.272727
# 11         Jason Holder           42   21.000000  116.666667        52.380952
#
#     avgbowlsfaced/inn  wickets  runs_conceded  overs  maiden  economy  \
# 0           18.500000       10            156   24.0       0    55.08
# 1           17.125000        6             83   12.1       0    41.80
# 2           17.125000        5            111   18.0       0    42.65
# 3           19.400000        8            146   18.0       0    49.74
# 4           20.800000        6            111   16.2       0    43.17
# 5            9.666667       11            165   26.0       0    45.25
# 6           14.625000       13            169   22.0       0    55.15
# 7           10.800000        6            185   23.3       0    57.41
# 8           10.666667        4             77   12.0       0    19.25
# 9            6.750000       11            198   31.0       0    52.25
# 10           9.200000        6            167   19.0       0    44.50
# 11          18.000000        5             49   10.2       0    14.01
#
#     bowling_Run_rate  StrikeRatebowling  bowling_average       team_y  \
# 0           6.500000          15.600000        14.400000     Zimbabwe
# 1           6.821918          13.833333        12.166667    Sri Lanka
# 2           6.166667          22.200000        21.600000     Zimbabwe
# 3           8.111111          18.250000        13.500000        India
# 4           6.795918          18.500000        16.333333      England
# 5           6.346154          15.000000        14.181818     Pakistan
# 6           7.681818          13.000000        10.153846  Netherlands
# 7           7.872340          30.833333        23.500000      Ireland
# 8           6.416667          19.250000        18.000000  Afghanistan
# 9           6.387097          18.000000        16.909091  Netherlands
# 10          8.789474          27.833333        19.000000   Bangladesh
# 11          4.741935           9.800000        12.400000  West Indies
#
#               bowlingStyle    battingStyle
# 0       Right arm Offbreak  Right hand Bat
# 1       Right arm Offbreak  Right hand Bat
# 2   Slow Left arm Orthodox   Left hand Bat
# 3    Right arm Medium fast  Right hand Bat
# 4    Right arm Fast medium   Left hand Bat
# 5                 Legbreak  Right hand Bat
# 6    Right arm Fast medium  Right hand Bat
# 7          Legbreak Googly  Right hand Bat
# 8          Legbreak Googly  Right hand Bat
# 9    Right arm Fast medium  Right hand Bat
# 10  Slow Left arm Orthodox   Left hand Bat
# 11   Right arm Medium fast  Right hand Bat

# %%
name=all_rounder_stats['Name']
runs=all_rounder_stats['runs_scored']
wickets=all_rounder_stats['wickets']

plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,8))
plt.scatter(runs,wickets)
plt.xlabel('runs scored')
plt.ylabel('wickets taken')
plt.title('all rounder Comparison ')
for i in range(all_rounder_stats.shape[0]):
     text=plt.text(x=runs[i]+0.3,y=wickets[i]+0.3,s=name[i],
                fontdict=dict(color='red',size=5))
        
plt.tight_layout()

# %%
 all_rounder_stats.to_excel("all_rounder_stats3.xlsx")

# %%
bowling_stats.to_excel("bowling_stats1.xlsx")

# %%
batting_stats.to_excel("batting_stats1.xlsx")
